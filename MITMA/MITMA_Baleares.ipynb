# %%
import os
import pandas as pd
import glob
from datetime import datetime
import gzip
import tarfile
import shutil

# %% [markdown]
# ### Definitions

# %%
# Function to filter each CSV file
def filter_csv(gz_file, prefixes, region):
	# Read the CSV file into a pandas DataFrame
	data = pd.read_csv(gz_file, dtype=data_types, sep="|")
	
	# Print column names for debugging
	print(f"Column names in {gz_file}: {', '.join(data.columns)}")
	
	# Apply the filter to keep rows where the origin and destination columns start with specified prefixes
	filtered_data = data[
		data["origen"].str.startswith(tuple(prefixes)) &
		data["destino"].str.startswith(tuple(prefixes))
	]
	
	# Define the output file name using the gz_file path
	output_file = os.path.splitext(os.path.basename(gz_file))[0] + "_" + region + ".csv"
	
	# Write the filtered data to a new CSV file
	filtered_data.to_csv(os.path.join(filtered_folder, output_file), index=False)

# Function to aggregate days
def aggregate_days(filtered_folder, criteria, output_file,):
	# Get a list of all CSV files in the folder
	file_list = glob.glob(os.path.join(filtered_folder, "*.csv"))
	# csv_files = glob.glob(os.path.join(folder_path, "*.csv"))
	
	# Initialize an empty list to store data frames
	data_list = []
	
	# Loop through each CSV file
	for file in file_list:
		# Extract the date part from the filename assuming format YYYYMMDD
		file_name = os.path.basename(file)
		date_str = file_name[:8]  # Assuming the first 8 characters are the date
		# year_month = date_str[:6]  # Extract YYYYMM
		
		# Convert thhe date_str to a datetime object
		file_date = datetime.strptime(date_str, "%Y%m%d")

		# Create a weekday flag (Monday=0, Sunday=6)
		weekday_flag = 1 if file_date.weekday() < 5 else 0

		# Read the data
		data = pd.read_csv(file, dtype=data_types, sep=",")
		data['date_str'] = date_str
		data['weekday_flag'] = weekday_flag
		data_list.append(data)
		
		# Print the total number of trips each day
		print(f"{file}: {data['viajes'].sum()}")
	
	# Combine all data frames into one
	combined_data = pd.concat(data_list, ignore_index=True)
	print(f"Total trips: {combined_data['viajes'].sum()}")

	grouping_criteria = criteria + ['date_str', 'weekday_flag']
	
	# The following line fills any NaN before grouping to prevent rows from being lost
	combined_data[grouping_criteria] = combined_data[grouping_criteria].fillna("Unknown")

	# Group by criteria and calculate the sums
	grouped_data = combined_data.groupby(grouping_criteria).agg(
		viajes=('viajes', 'sum'),
		viajes_km=('viajes_km', 'sum')
	).reset_index()

	print(f"Output trips({output_file}): {grouped_data['viajes'].sum()}")
	print(f"Output trip-kilometers({output_file}): {grouped_data['viajes_km'].sum()}")

	# Write the filtered data to a new CSV file
	grouped_data.drop_duplicates(inplace = True)
	grouped_data.to_csv(os.path.join(output_folder, output_file), index=False)

# %% [markdown]
# ### Pseudo main

# %%
# Define working folder. We'll work in parallel with the 3 possible subdivisions (GAU, municipality, census district)
working_folder = "D:/Documents/Proyectos/MITMA/Data/"

# Define sub-folders
tar_file_path = os.path.join(working_folder, "0-meses_completos/")
gz_file_path = os.path.join(working_folder, "1-Unzipped_meses_completos/")
raw_files = os.path.join(working_folder, "1-Unzipped/")
filtered_folder = os.path.join(working_folder,"2-Baleares/")
output_folder = os.path.join(working_folder,"3-Results/")
zones_shp = os.path.join(working_folder, "Zonificación_GAUs/")
# output_folder = os.path.join(working_folder, "3-Averages/")

# Create a temporary folder to store the .gz files inside each .tar file
tmp_folder = os.path.join(working_folder, "1-tmp")
if os.path.exists(tmp_folder):
	shutil.rmtree(tmp_folder)
os.makedirs(tmp_folder)

# Define datatypes
data_types = {"origen": 'string',
			  "destino": 'string', 
			  "distancia": 'string',
			  "actividad_origen": 'string',
			  "actividad_destino": 'string',
			  "residencia": 'string',
			  "renta": 'string',
			  "edad": 'string',
			  "sexo": 'string'
}

criteria = list(data_types.keys())

# Define columns with quantities to group
os.makedirs(filtered_folder, exist_ok=True)
prefixes = ["07"]
region = "Baleares"

tar_pattern = os.path.join(tar_file_path, "*.tar")
tar_file_list = glob.glob(tar_pattern)
pattern = os.path.join(raw_files, "*.csv")
file_list = glob.glob(pattern)
output_file = region + "_MITMA.csv"


list_dates = ['20230124','20230125','20230126','20230221','20230222','20230223','20230307','20230308','20230309',
			'20230418','20230419','20230420', '20230509','20230510','20230511', '20230606','20230607','20230608',
			'20230718','20230719','20230720', '20230808','20230809','20230810', '20230905','20230906','20230907',
			'20231003', '20231004','20231005','20231107','20231108', '20231109','20231212','20231213','20231214',
			]

# Apply the filter function to each .tar file
for tar_file in tar_file_list:
	with tarfile.open(tar_file, 'r') as tar:
		tar.extractall(path=tmp_folder)
		for gz_file in tar.getmembers():
			if gz_file.name.endswith('.gz'):
				if any(date in gz_file.name for date in list_dates):
					gz_file_path = os.path.join(tmp_folder, gz_file.name)
					filter_csv(gz_file_path, prefixes, region)

		# Clear the tmp_folder after processing each tar file
		shutil.rmtree(tmp_folder)
		os.makedirs(tmp_folder)  # Recreate the tmp folder

aggregate_days(filtered_folder, criteria, output_file)
# Out:
# Column names in D:/Documents/Proyectos/MITMA/Data/1-tmp\20230124_Viajes_distritos.csv.gz: fecha, periodo, origen, destino, distancia, actividad_origen, actividad_destino, estudio_origen_posible, estudio_destino_posible, residencia, renta, edad, sexo, viajes, viajes_km
# Column names in D:/Documents/Proyectos/MITMA/Data/1-tmp\20230125_Viajes_distritos.csv.gz: fecha, periodo, origen, destino, distancia, actividad_origen, actividad_destino, estudio_origen_posible, estudio_destino_posible, residencia, renta, edad, sexo, viajes, viajes_km
# Column names in D:/Documents/Proyectos/MITMA/Data/1-tmp\20230126_Viajes_distritos.csv.gz: fecha, periodo, origen, destino, distancia, actividad_origen, actividad_destino, estudio_origen_posible, estudio_destino_posible, residencia, renta, edad, sexo, viajes, viajes_km
# Column names in D:/Documents/Proyectos/MITMA/Data/1-tmp\20230221_Viajes_distritos.csv.gz: fecha, periodo, origen, destino, distancia, actividad_origen, actividad_destino, estudio_origen_posible, estudio_destino_posible, residencia, renta, edad, sexo, viajes, viajes_km
# Column names in D:/Documents/Proyectos/MITMA/Data/1-tmp\20230222_Viajes_distritos.csv.gz: fecha, periodo, origen, destino, distancia, actividad_origen, actividad_destino, estudio_origen_posible, estudio_destino_posible, residencia, renta, edad, sexo, viajes, viajes_km
# Column names in D:/Documents/Proyectos/MITMA/Data/1-tmp\20230223_Viajes_distritos.csv.gz: fecha, periodo, origen, destino, distancia, actividad_origen, actividad_destino, estudio_origen_posible, estudio_destino_posible, residencia, renta, edad, sexo, viajes, viajes_km
# Column names in D:/Documents/Proyectos/MITMA/Data/1-tmp\20230307_Viajes_distritos.csv.gz: fecha, periodo, origen, destino, distancia, actividad_origen, actividad_destino, estudio_origen_posible, estudio_destino_posible, residencia, renta, edad, sexo, viajes, viajes_km
# Column names in D:/Documents/Proyectos/MITMA/Data/1-tmp\20230308_Viajes_distritos.csv.gz: fecha, periodo, origen, destino, distancia, actividad_origen, actividad_destino, estudio_origen_posible, estudio_destino_posible, residencia, renta, edad, sexo, viajes, viajes_km
# Column names in D:/Documents/Proyectos/MITMA/Data/1-tmp\20230309_Viajes_distritos.csv.gz: fecha, periodo, origen, destino, distancia, actividad_origen, actividad_destino, estudio_origen_posible, estudio_destino_posible, residencia, renta, edad, sexo, viajes, viajes_km
# Column names in D:/Documents/Proyectos/MITMA/Data/1-tmp\20230418_Viajes_distritos.csv.gz: fecha, periodo, origen, destino, distancia, actividad_origen, actividad_destino, estudio_origen_posible, estudio_destino_posible, residencia, renta, edad, sexo, viajes, viajes_km
# Column names in D:/Documents/Proyectos/MITMA/Data/1-tmp\20230419_Viajes_distritos.csv.gz: fecha, periodo, origen, destino, distancia, actividad_origen, actividad_destino, estudio_origen_posible, estudio_destino_posible, residencia, renta, edad, sexo, viajes, viajes_km
# Column names in D:/Documents/Proyectos/MITMA/Data/1-tmp\20230420_Viajes_distritos.csv.gz: fecha, periodo, origen, destino, distancia, actividad_origen, actividad_destino, estudio_origen_posible, estudio_destino_posible, residencia, renta, edad, sexo, viajes, viajes_km
# Column names in D:/Documents/Proyectos/MITMA/Data/1-tmp\20230509_Viajes_distritos.csv.gz: fecha, periodo, origen, destino, distancia, actividad_origen, actividad_destino, estudio_origen_posible, estudio_destino_posible, residencia, renta, edad, sexo, viajes, viajes_km
# Column names in D:/Documents/Proyectos/MITMA/Data/1-tmp\20230510_Viajes_distritos.csv.gz: fecha, periodo, origen, destino, distancia, actividad_origen, actividad_destino, estudio_origen_posible, estudio_destino_posible, residencia, renta, edad, sexo, viajes, viajes_km
# Column names in D:/Documents/Proyectos/MITMA/Data/1-tmp\20230511_Viajes_distritos.csv.gz: fecha, periodo, origen, destino, distancia, actividad_origen, actividad_destino, estudio_origen_posible, estudio_destino_posible, residencia, renta, edad, sexo, viajes, viajes_km
# Column names in D:/Documents/Proyectos/MITMA/Data/1-tmp\20230606_Viajes_distritos.csv.gz: fecha, periodo, origen, destino, distancia, actividad_origen, actividad_destino, estudio_origen_posible, estudio_destino_posible, residencia, renta, edad, sexo, viajes, viajes_km
# Column names in D:/Documents/Proyectos/MITMA/Data/1-tmp\20230607_Viajes_distritos.csv.gz: fecha, periodo, origen, destino, distancia, actividad_origen, actividad_destino, estudio_origen_posible, estudio_destino_posible, residencia, renta, edad, sexo, viajes, viajes_km
# Column names in D:/Documents/Proyectos/MITMA/Data/1-tmp\20230608_Viajes_distritos.csv.gz: fecha, periodo, origen, destino, distancia, actividad_origen, actividad_destino, estudio_origen_posible, estudio_destino_posible, residencia, renta, edad, sexo, viajes, viajes_km
# Column names in D:/Documents/Proyectos/MITMA/Data/1-tmp\20230718_Viajes_distritos.csv.gz: fecha, periodo, origen, destino, distancia, actividad_origen, actividad_destino, estudio_origen_posible, estudio_destino_posible, residencia, renta, edad, sexo, viajes, viajes_km
# Column names in D:/Documents/Proyectos/MITMA/Data/1-tmp\20230719_Viajes_distritos.csv.gz: fecha, periodo, origen, destino, distancia, actividad_origen, actividad_destino, estudio_origen_posible, estudio_destino_posible, residencia, renta, edad, sexo, viajes, viajes_km
# Column names in D:/Documents/Proyectos/MITMA/Data/1-tmp\20230720_Viajes_distritos.csv.gz: fecha, periodo, origen, destino, distancia, actividad_origen, actividad_destino, estudio_origen_posible, estudio_destino_posible, residencia, renta, edad, sexo, viajes, viajes_km
# Column names in D:/Documents/Proyectos/MITMA/Data/1-tmp\20230808_Viajes_distritos.csv.gz: fecha, periodo, origen, destino, distancia, actividad_origen, actividad_destino, estudio_origen_posible, estudio_destino_posible, residencia, renta, edad, sexo, viajes, viajes_km
# Column names in D:/Documents/Proyectos/MITMA/Data/1-tmp\20230809_Viajes_distritos.csv.gz: fecha, periodo, origen, destino, distancia, actividad_origen, actividad_destino, estudio_origen_posible, estudio_destino_posible, residencia, renta, edad, sexo, viajes, viajes_km
# Column names in D:/Documents/Proyectos/MITMA/Data/1-tmp\20230810_Viajes_distritos.csv.gz: fecha, periodo, origen, destino, distancia, actividad_origen, actividad_destino, estudio_origen_posible, estudio_destino_posible, residencia, renta, edad, sexo, viajes, viajes_km
# Column names in D:/Documents/Proyectos/MITMA/Data/1-tmp\20230905_Viajes_distritos.csv.gz: fecha, periodo, origen, destino, distancia, actividad_origen, actividad_destino, estudio_origen_posible, estudio_destino_posible, residencia, renta, edad, sexo, viajes, viajes_km
# Column names in D:/Documents/Proyectos/MITMA/Data/1-tmp\20230906_Viajes_distritos.csv.gz: fecha, periodo, origen, destino, distancia, actividad_origen, actividad_destino, estudio_origen_posible, estudio_destino_posible, residencia, renta, edad, sexo, viajes, viajes_km
# Column names in D:/Documents/Proyectos/MITMA/Data/1-tmp\20230907_Viajes_distritos.csv.gz: fecha, periodo, origen, destino, distancia, actividad_origen, actividad_destino, estudio_origen_posible, estudio_destino_posible, residencia, renta, edad, sexo, viajes, viajes_km
# Column names in D:/Documents/Proyectos/MITMA/Data/1-tmp\20231003_Viajes_distritos.csv.gz: fecha, periodo, origen, destino, distancia, actividad_origen, actividad_destino, estudio_origen_posible, estudio_destino_posible, residencia, renta, edad, sexo, viajes, viajes_km
# Column names in D:/Documents/Proyectos/MITMA/Data/1-tmp\20231004_Viajes_distritos.csv.gz: fecha, periodo, origen, destino, distancia, actividad_origen, actividad_destino, estudio_origen_posible, estudio_destino_posible, residencia, renta, edad, sexo, viajes, viajes_km
# Column names in D:/Documents/Proyectos/MITMA/Data/1-tmp\20231005_Viajes_distritos.csv.gz: fecha, periodo, origen, destino, distancia, actividad_origen, actividad_destino, estudio_origen_posible, estudio_destino_posible, residencia, renta, edad, sexo, viajes, viajes_km
# Column names in D:/Documents/Proyectos/MITMA/Data/1-tmp\20231107_Viajes_distritos.csv.gz: fecha, periodo, origen, destino, distancia, actividad_origen, actividad_destino, estudio_origen_posible, estudio_destino_posible, residencia, renta, edad, sexo, viajes, viajes_km
# Column names in D:/Documents/Proyectos/MITMA/Data/1-tmp\20231108_Viajes_distritos.csv.gz: fecha, periodo, origen, destino, distancia, actividad_origen, actividad_destino, estudio_origen_posible, estudio_destino_posible, residencia, renta, edad, sexo, viajes, viajes_km
# Column names in D:/Documents/Proyectos/MITMA/Data/1-tmp\20231109_Viajes_distritos.csv.gz: fecha, periodo, origen, destino, distancia, actividad_origen, actividad_destino, estudio_origen_posible, estudio_destino_posible, residencia, renta, edad, sexo, viajes, viajes_km
# Column names in D:/Documents/Proyectos/MITMA/Data/1-tmp\20231212_Viajes_distritos.csv.gz: fecha, periodo, origen, destino, distancia, actividad_origen, actividad_destino, estudio_origen_posible, estudio_destino_posible, residencia, renta, edad, sexo, viajes, viajes_km
# Column names in D:/Documents/Proyectos/MITMA/Data/1-tmp\20231213_Viajes_distritos.csv.gz: fecha, periodo, origen, destino, distancia, actividad_origen, actividad_destino, estudio_origen_posible, estudio_destino_posible, residencia, renta, edad, sexo, viajes, viajes_km
# Column names in D:/Documents/Proyectos/MITMA/Data/1-tmp\20231214_Viajes_distritos.csv.gz: fecha, periodo, origen, destino, distancia, actividad_origen, actividad_destino, estudio_origen_posible, estudio_destino_posible, residencia, renta, edad, sexo, viajes, viajes_km
# D:/Documents/Proyectos/MITMA/Data/2-Baleares\20230124_Viajes_distritos.csv_Baleares.csv: 3552456.2490000003
# D:/Documents/Proyectos/MITMA/Data/2-Baleares\20230125_Viajes_distritos.csv_Baleares.csv: 3500965.750126031
# D:/Documents/Proyectos/MITMA/Data/2-Baleares\20230126_Viajes_distritos.csv_Baleares.csv: 3611966.76
# D:/Documents/Proyectos/MITMA/Data/2-Baleares\20230221_Viajes_distritos.csv_Baleares.csv: 3727138.4239999987
# D:/Documents/Proyectos/MITMA/Data/2-Baleares\20230222_Viajes_distritos.csv_Baleares.csv: 3710502.7690000003
# D:/Documents/Proyectos/MITMA/Data/2-Baleares\20230223_Viajes_distritos.csv_Baleares.csv: 3685107.062999999
# D:/Documents/Proyectos/MITMA/Data/2-Baleares\20230307_Viajes_distritos.csv_Baleares.csv: 3759100.593999999
# D:/Documents/Proyectos/MITMA/Data/2-Baleares\20230308_Viajes_distritos.csv_Baleares.csv: 3775789.2909999997
# D:/Documents/Proyectos/MITMA/Data/2-Baleares\20230309_Viajes_distritos.csv_Baleares.csv: 3780115.397
# D:/Documents/Proyectos/MITMA/Data/2-Baleares\20230418_Viajes_distritos.csv_Baleares.csv: 3922475.6909999982
# D:/Documents/Proyectos/MITMA/Data/2-Baleares\20230419_Viajes_distritos.csv_Baleares.csv: 3951766.894999999
# D:/Documents/Proyectos/MITMA/Data/2-Baleares\20230420_Viajes_distritos.csv_Baleares.csv: 3952495.1959999995
# D:/Documents/Proyectos/MITMA/Data/2-Baleares\20230509_Viajes_distritos.csv_Baleares.csv: 3997647.1020000004
# D:/Documents/Proyectos/MITMA/Data/2-Baleares\20230510_Viajes_distritos.csv_Baleares.csv: 3972263.074
# D:/Documents/Proyectos/MITMA/Data/2-Baleares\20230511_Viajes_distritos.csv_Baleares.csv: 3975056.2060000002
# D:/Documents/Proyectos/MITMA/Data/2-Baleares\20230606_Viajes_distritos.csv_Baleares.csv: 4029317.2340000006
# D:/Documents/Proyectos/MITMA/Data/2-Baleares\20230607_Viajes_distritos.csv_Baleares.csv: 3991138.041
# D:/Documents/Proyectos/MITMA/Data/2-Baleares\20230608_Viajes_distritos.csv_Baleares.csv: 4044355.0910000005
# D:/Documents/Proyectos/MITMA/Data/2-Baleares\20230718_Viajes_distritos.csv_Baleares.csv: 3880310.1709999996
# D:/Documents/Proyectos/MITMA/Data/2-Baleares\20230719_Viajes_distritos.csv_Baleares.csv: 3825903.4829999995
# D:/Documents/Proyectos/MITMA/Data/2-Baleares\20230720_Viajes_distritos.csv_Baleares.csv: 3840977.1679999996
# D:/Documents/Proyectos/MITMA/Data/2-Baleares\20230808_Viajes_distritos.csv_Baleares.csv: 3690187.1080000005
# D:/Documents/Proyectos/MITMA/Data/2-Baleares\20230809_Viajes_distritos.csv_Baleares.csv: 3846007.668999999
# D:/Documents/Proyectos/MITMA/Data/2-Baleares\20230810_Viajes_distritos.csv_Baleares.csv: 3861922.079
# D:/Documents/Proyectos/MITMA/Data/2-Baleares\20230905_Viajes_distritos.csv_Baleares.csv: 3813043.6550000003
# D:/Documents/Proyectos/MITMA/Data/2-Baleares\20230906_Viajes_distritos.csv_Baleares.csv: 3819765.2629999993
# D:/Documents/Proyectos/MITMA/Data/2-Baleares\20230907_Viajes_distritos.csv_Baleares.csv: 3839220.309
# D:/Documents/Proyectos/MITMA/Data/2-Baleares\20231003_Viajes_distritos.csv_Baleares.csv: 3852122.0319999997
# D:/Documents/Proyectos/MITMA/Data/2-Baleares\20231004_Viajes_distritos.csv_Baleares.csv: 3852365.0649999995
# D:/Documents/Proyectos/MITMA/Data/2-Baleares\20231005_Viajes_distritos.csv_Baleares.csv: 3858994.5480000004
# D:/Documents/Proyectos/MITMA/Data/2-Baleares\20231107_Viajes_distritos.csv_Baleares.csv: 3654362.0920000006
# D:/Documents/Proyectos/MITMA/Data/2-Baleares\20231108_Viajes_distritos.csv_Baleares.csv: 3655005.971999999
# D:/Documents/Proyectos/MITMA/Data/2-Baleares\20231109_Viajes_distritos.csv_Baleares.csv: 3586545.0230000005
# D:/Documents/Proyectos/MITMA/Data/2-Baleares\20231212_Viajes_distritos.csv_Baleares.csv: 3597199.8570000003
# D:/Documents/Proyectos/MITMA/Data/2-Baleares\20231213_Viajes_distritos.csv_Baleares.csv: 3599457.5940000005
# D:/Documents/Proyectos/MITMA/Data/2-Baleares\20231214_Viajes_distritos.csv_Baleares.csv: 3591721.436000001
# Total trips: 136604767.35112593
# Output trips(Baleares_MITMA.csv): 136604767.35112602
# Output trip-kilometers(Baleares_MITMA.csv): 947348112.1733563

# %% [markdown]
# ### Date substitution routine

# %% [markdown]
# file1 = "D:/Documents/Proyectos/MITMA/Data/3-Results/Leon_Mitma.csv"
# file2 = "D:/Documents/Proyectos/MITMA/Data/3-Results/Leon_Mitma_week_Oct.csv"
# output = "D:/Documents/Proyectos/MITMA/Data/3-Results/Leon_Mitma_new.csv"
#
# dates = ['20231002',
#          '20231003',
#          '20231004',
#          '20231005',
#          '20231006',
#          '20231007',
#          '20231008']
#
#
# df1 = pd.read_csv(file1)
# df1['date_str'] = df1['date_str'].astype(str)
# df1.drop(df1[df1['date_str'].isin(dates)].index, inplace=True)
# df2 = pd.read_csv(file2)
# df1 = pd.concat([df1, df2])
# df1.to_csv(output, index=False)
